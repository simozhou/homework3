# %%
import ttest
import matplotlib.pyplot as plt
import time

# %% [markdown]
# **first thing first**, we create an instance of the TimeTest object, which will take care of generating random arrays (you can also choose between an easy_logarithm ['e_log'] (array of sizes 10, 100, 1000, 10000 and 100000) or to create a log space (results are more precise but performance is taken down by the merge sort).
# After out Timetest object is instanciated, we run the test_it function, which will take care of filling up our dataframe with all the values we need for our statistics.

# %%
test1 = ttest.TimeTest()
start = time.time()
test1.test_it()
end = time.time() - start

print(end)
# Out:
# time test generated!
# sorting timing done!
# binary insertion, get random, get max and deletion timing done!
# heap insertion, get max and deletion timing done!
# 230.34637546539307

# %% [markdown]
# We peek on the results:

# %%
test1.test_result.head()
# Out:
#     binary_delete  binary_delete_se  binary_get_max  binary_get_max_se  \
# 10       0.000006      2.156538e-07        0.000019       7.904764e-08
# 12       0.000006      1.993892e-07        0.000022       6.490406e-08
# 14       0.000006      1.805880e-07        0.000022       3.638347e-07
# 17       0.000006      2.026356e-07        0.000022       6.337006e-08
# 21       0.000006      2.653685e-07        0.000025       6.238009e-08
#
#     binary_get_random  binary_get_random_se  binary_insertion  \
# 10           0.000233          7.295176e-06          0.000007
# 12           0.000231          4.683796e-06          0.000007
# 14           0.000280          2.171661e-07          0.000007
# 17           0.000281          7.543327e-07          0.000007
# 21           0.000283          3.720262e-06          0.000007
#
#     binary_insertion_se  heap_get_max  heap_get_max_se  heap_insert  \
# 10         2.704127e-07      0.000001     5.521781e-08     0.000001
# ...

# %% [markdown]
# The summary function will present the collected data in plots, giving also information about the machine on which those analysis have been performed. There is the possibility to get a **pdf report** out of this analysis by flagging *True* the pdf_report kwarg.

# %% [markdown]
# the sampling procedure is set up as follows:
# - each value of each graph is a sample mean $\bar{x}$, and has a standard error $\frac{\sigma_{sample}}{\sqrt{n}}$ from which we calculate the confidence interval for each point on the graph $\bar{x} \pm \frac{\sigma_{sample}}{\sqrt{n}}z_{(1-\frac{\alpha}{2})}$ [**note**: we have found out that the quick sort and merge sort were giving optimal fits even without the sampling procedure (which would have made it heavily slower), so Quick Sort and Merge sort test is executed only once and taken for good]

# %%
test1.summary(pdf_report=False)
# Out:
# Python version  : 3.6.2
# compiler        : MSC v.1900 32 bit (Intel)
#
# system     : Windows
# release    : 10
# machine    : AMD64
# processor  : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# interpreter: 32bit

# %% [markdown]
# We can also create, for further analysis, a csv file of this analysis by simply calling the csv function:

# %%
test1.csv()
# Out:
# csv file written! check current directory
