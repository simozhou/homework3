# %%
import ttest
import matplotlib.pyplot as plt
import time

# %% [markdown]
# **first thing first**, we create an instance of the TimeTest object, which will take care of generating random arrays (you can also choose between an easy_logarithm ['e_log'] (array of sizes 10, 100, 1000, 10000 and 100000) or to create a log space (results are more precise but performance is taken down by the merge sort).
# After out Timetest object is instanciated, we run the test_it function, which will take care of filling up our dataframe with all the values we need for our statistics.

# %%
test1 = ttest.TimeTest('e_log')
start = time.time()
test1.test_it()
end = time.time() - start

print(end)
# Out:
# time test generated!
# sorting timing done!
# binary insertion, get random, get max and deletion timing done!
# heap insertion, get max and deletion timing done!
# 69.84723424911499

# %% [markdown]
# We peek on the results:

# %%
test1.test_result.head()
# Out:
#         binary_delete  binary_delete_se  binary_get_max  binary_get_max_se  \
# 10           0.000007      3.674644e-07        0.000013       3.933234e-07
# 100          0.000010      7.222547e-07        0.000022       2.324567e-07
# 1000         0.000013      6.555326e-07        0.000030       1.620675e-06
# 10000        0.000017      1.317008e-06        0.000037       1.064071e-05
# 100000       0.000022      3.998905e-06        0.000041       7.050841e-06
#
#         binary_get_random  binary_get_random_se  binary_insertion  \
# 10               0.000304              0.000017          0.000008
# 100              0.000462              0.000014          0.000012
# 1000             0.000646              0.000039          0.000018
# 10000            0.001296              0.000100          0.000025
# 100000           0.001370              0.000108          0.000024
#
#         binary_insertion_se  heap_get_max  heap_get_max_se  heap_insert  \
# 10             3.706146e-07      0.000001     7.163278e-08     0.000001
# 100            1.192981e-06      0.000001     1.308540e-07     0.000001
# 1000           1.055305e-06      0.000001     1.290658e-07     0.000002
# 10000          2.477602e-06      0.000001     3.456160e-07     0.000005
# 100000         1.798862e-06      0.000001     1.299988e-07     0.000005
#
#         heap_insert_se  heap_remove  heap_remove_se  merge_sort  quick_sort
# 10        4.857223e-08     0.000001    4.097059e-08    0.000395    0.000183
# 100       7.890781e-08     0.000001    7.531112e-08    0.007159    0.002203
# 1000      2.249369e-07     0.000003    3.074681e-07    0.105153    0.033805
# 10000     1.208089e-07     0.000006    3.467007e-07    1.488479    0.469757
# 100000    1.039733e-07     0.000007    1.483776e-07   26.339256    5.325302

# %% [markdown]
# The summary function will present the collected data in plots, giving also information about the machine on which those analysis have been performed. There is the possibility by flagging *True* the pdf_report kwarg.

# %%
test1.summary(pdf_report=False)
# Out:
# Python version  : 3.6.2
# compiler        : MSC v.1900 32 bit (Intel)
#
# system     : Windows
# release    : 10
# machine    : AMD64
# processor  : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# interpreter: 32bit

# %%
plt.errorbar(test1.test_result.heap_insert.index, test1.test_result.heap_insert, test1.test_result.heap_insert_se)
plt.xscale('log')
plt.show()

# %% [markdown]
# DEAD WRONG FUNCTION
